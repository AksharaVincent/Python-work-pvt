# %%
import pandas as pd 
sales = pd.read_csv('Oorjja.csv')
sales
sales.head() #head() will shows 1st 5 rows of the data
sales.tail() #tail() shows the last 5 rows
sales.head(4)
sales.tail(4)
sales.head(6)
sales.tail(6)
sales.head(8)
sales.tail(8)
sales.head(10)
sales.tail(10)
# Out:
#                           Timestamp             NAME  \
# 9   2022/05/26 10:13:54 AM GMT+5:30      Soul Joseph
# 10  2023/04/04 11:24:37 AM GMT+5:30      Liya Roslin
# 11  2023/04/04 11:25:15 AM GMT+5:30         Alfy N P
# 12  2023/04/04 11:25:32 AM GMT+5:30         ANJU P K
# 13  2023/04/04 11:28:59 AM GMT+5:30      Jiyamol Joy
# 14  2023/04/04 11:29:26 AM GMT+5:30       Rithun P C
# 15  2023/04/04 11:29:32 AM GMT+5:30  Akshara Vincent
# 16  2023/04/04 11:29:46 AM GMT+5:30          Ajesh C
# 17  2023/04/04 11:31:27 AM GMT+5:30        Athira pv
# 18  2023/04/04 11:31:38 AM GMT+5:30   Remya Raghavan
#
#                                                 Place Designation  GENDER  \
# 9                               Kanjikuzhi, Alappuzha     Student    MALE
# 10                                          Manjummel     Student  FEMALE
# 11                            Thekkenmalipuram, Vypin     Student  FEMALE
# 12                                          KOZHIKODE     Student  FEMALE
# ...
