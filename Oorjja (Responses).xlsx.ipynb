# %%
import pandas as pd
data = pd.read_excel('Oorjja (Responses).xlsx')
data
#data.head() #head() will shows 1st 10 rows of the data
#data.tail() #tail() will shows the last 10rows
# Out:
#                 Timestamp                Email address             Name  \
# 0 2023-04-12 10:02:14.576       rithunhomiez@gmail.com       Rithun P C
# 1 2023-04-12 10:02:48.677           anjupk84@gmail.com         Anju P K
# 2 2023-04-12 10:04:18.475    aksharavincent7@gmail.com  Akshara Vincent
# 3 2023-04-12 10:06:17.104         ajeshc1992@gmail.com          Ajesh C
# 4 2023-04-12 10:08:34.463     jiyaparackal00@gmail.com      Jiyamol Joy
# 5 2023-04-12 10:08:47.065      Kanjanyathira@gmail.com        Athira pv
# 6 2023-04-12 10:09:44.593         alfynp2000@gmail.com         Alfy N P
# 7 2023-04-12 10:10:12.832    christy123johns@gmail.com    Christy Johns
# 8 2023-04-12 10:14:03.385  remyaraghavan1999@gmail.com   Remya Raghavan
# 9 2023-04-12 10:15:21.457    christy231johns@gmail.com  Catherine Johns
#
#     District Designation  Gender Blood grouop                Education  Age  \
# 0  Kozhikode     Trainee    Male         B+ve      Degree (Graduation)   27
# ...

# %%
data.max()
# Out:
# Timestamp                                  2023-04-12 10:15:21.457000
# Email address                                  rithunhomiez@gmail.com
# Name                                                       Rithun P C
# District                                                     Thrissur
# Designation                                                   Trainee
# Gender                                                           Male
# Blood grouop                                                     O-ve
# Education                                     Degree(Post Graduation)
# Age                                                                30
# Family members                                                    5-6
# Shirt size                                                         XS
# No. of knives at home                                             4-6
# No. of chairs at home                                            6-10
# ...

# %%
data.shape
# Out:
# (10, 21)

# %%
data.min()
# Out:
# Timestamp                                  2023-04-12 10:02:14.576000
# Email address                                 Kanjanyathira@gmail.com
# Name                                                          Ajesh C
# District                                                    Alappuzha
# Designation                                                    Mentor
# Gender                                                         Female
# Blood grouop                                                     A+ve
# Education                                     12th (Higher Secondary)
# Age                                                                21
# Family members                                                    3-4
# Shirt size                                                          M
# No. of knives at home                                             0-3
# No. of chairs at home                                             0-5
# ...

# %%
data.head(4)
data.tail(4)
# Out:
#                 Timestamp                Email address             Name  \
# 6 2023-04-12 10:09:44.593         alfynp2000@gmail.com         Alfy N P
# 7 2023-04-12 10:10:12.832    christy123johns@gmail.com    Christy Johns
# 8 2023-04-12 10:14:03.385  remyaraghavan1999@gmail.com   Remya Raghavan
# 9 2023-04-12 10:15:21.457    christy231johns@gmail.com  Catherine Johns
#
#     District Designation  Gender Blood grouop                Education  Age  \
# 6  Ernakulam     Trainee  Female         B+ve      Degree (Graduation)   22
# 7  Ernakulam      Mentor  Female         O+ve  Degree(Post Graduation)   24
# 8  Ernakulam     Trainee  Female         O+ve      Degree (Graduation)   23
# 9     Idukki      Mentor  Female         O-ve      Degree (Graduation)   21
#
#   Family members  ... No. of knives at home No. of chairs at home  \
# 6            3-4  ...                   0-3                   0-5
# 7            3-4  ...                   4-6                 11-15
# ...

# %%
data.count()
# Out:
# Timestamp                                  10
# Email address                              10
# Name                                       10
# District                                   10
# Designation                                10
# Gender                                     10
# Blood grouop                               10
# Education                                  10
# Age                                        10
# Family members                             10
# Shirt size                                 10
# No. of knives at home                      10
# No. of chairs at home                      10
# Favorite color (mention only one)          10
# Liter of milk bought in home               10
# Height ( in cm)                            10
# Weight ( in Kg)                            10
# which is your favorite subject             10
# Which is your favorite Software            10
# How many liter of water you drink daily    10
# ...

# %%
data.columns
# Out:
# Index(['Timestamp', 'Email address', 'Name', 'District', 'Designation',
#        'Gender', 'Blood grouop', 'Education', 'Age', 'Family members',
#        'Shirt size', 'No. of knives at home', 'No. of chairs at home',
#        'Favorite color (mention only one)', 'Liter of milk bought in home',
#        'Height ( in cm)', 'Weight ( in Kg)', 'which is your favorite subject',
#        'Which is your favorite Software',
#        'How many liter of water you drink daily', 'Favorite food '],
#       dtype='object')

# %%
d={"name": "Alfy N P","Height":145}
print(d)
# Out:
# {'name': 'Alfy N P', 'Height': 145}

# %%
data.mean()
# Out:
# C:\Users\vantl\AppData\Local\Temp\ipykernel_19776\531903386.py:1: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   data.mean()
# C:\Users\vantl\AppData\Local\Temp\ipykernel_19776\531903386.py:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.mean()
# Age                                         24.70
# Height ( in cm)                            154.00
# Weight ( in Kg)                             52.90
# How many liter of water you drink daily      1.61
# dtype: float64

# %%
data.median()
# Out:
# C:\Users\vantl\AppData\Local\Temp\ipykernel_19776\4184645713.py:1: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   data.median()
# C:\Users\vantl\AppData\Local\Temp\ipykernel_19776\4184645713.py:1: FutureWarning: The default value of numeric_only in DataFrame.median is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.median()
# Age                                         23.50
# Height ( in cm)                            152.50
# Weight ( in Kg)                             49.50
# How many liter of water you drink daily      1.75
# dtype: float64

# %%
data.mode() #mode
# Out:
#                 Timestamp                Email address             Name  \
# 0 2023-04-12 10:02:14.576      Kanjanyathira@gmail.com          Ajesh C
# 1 2023-04-12 10:02:48.677         ajeshc1992@gmail.com  Akshara Vincent
# 2 2023-04-12 10:04:18.475    aksharavincent7@gmail.com         Alfy N P
# 3 2023-04-12 10:06:17.104         alfynp2000@gmail.com         Anju P K
# 4 2023-04-12 10:08:34.463           anjupk84@gmail.com        Athira pv
# 5 2023-04-12 10:08:47.065    christy123johns@gmail.com  Catherine Johns
# 6 2023-04-12 10:09:44.593    christy231johns@gmail.com    Christy Johns
# 7 2023-04-12 10:10:12.832     jiyaparackal00@gmail.com      Jiyamol Joy
# 8 2023-04-12 10:14:03.385  remyaraghavan1999@gmail.com   Remya Raghavan
# 9 2023-04-12 10:15:21.457       rithunhomiez@gmail.com       Rithun P C
#
#     District Designation  Gender Blood grouop            Education   Age  \
# 0  Ernakulam     Trainee  Female         B+ve  Degree (Graduation)  21.0
# ...

# %%
data['Age']
# Out:
# 0    27
# 1    29
# 2    21
# 3    30
# 4    27
# 5    23
# 6    22
# 7    24
# 8    23
# 9    21
# Name: Age, dtype: int64

# %%
data[['Age']]
# Out:
#    Age
# 0   27
# 1   29
# 2   21
# 3   30
# 4   27
# 5   23
# 6   22
# 7   24
# 8   23
# 9   21

# %%
data[['Age','Gender']]
# Out:
#    Age  Gender
# 0   27    Male
# 1   29  Female
# 2   21  Female
# 3   30    Male
# 4   27  Female
# 5   23  Female
# 6   22  Female
# 7   24  Female
# 8   23  Female
# 9   21  Female

# %%
data[['Age']].head()
# Out:
#    Age
# 0   27
# 1   29
# 2   21
# 3   30
# 4   27

# %%
data[['Gender']].tail()
# Out:
#    Gender
# 5  Female
# 6  Female
# 7  Female
# 8  Female
# 9  Female

# %%
data.sample(2)
# Out:
#                 Timestamp              Email address             Name  \
# 9 2023-04-12 10:15:21.457  christy231johns@gmail.com  Catherine Johns
# 2 2023-04-12 10:04:18.475  aksharavincent7@gmail.com  Akshara Vincent
#
#   District Designation  Gender Blood grouop                Education  Age  \
# 9   Idukki      Mentor  Female         O-ve      Degree (Graduation)   21
# 2   Kannur     Trainee  Female         O+ve  12th (Higher Secondary)   21
#
#   Family members  ... No. of knives at home No. of chairs at home  \
# 9            3-4  ...                   0-3                16- 20
# 2            3-4  ...                   4-6                  6-10
#
#   Favorite color (mention only one) Liter of milk bought in home  \
# 9                             Black                   Not buying
# 2                             Black                      0.5 - 1
#
#   Height ( in cm)  Weight ( in Kg)  which is your favorite subject  \
# ...

# %%
data.sample(2)
# Out:
#                 Timestamp              Email address           Name  \
# 5 2023-04-12 10:08:47.065    Kanjanyathira@gmail.com      Athira pv
# 7 2023-04-12 10:10:12.832  christy123johns@gmail.com  Christy Johns
#
#     District Designation  Gender Blood grouop                Education  Age  \
# 5   Thrissur     Trainee  Female         A+ve      Degree (Graduation)   23
# 7  Ernakulam      Mentor  Female         O+ve  Degree(Post Graduation)   24
#
#   Family members  ... No. of knives at home No. of chairs at home  \
# 5            3-4  ...                   4-6                  6-10
# 7            3-4  ...                   4-6                 11-15
#
#   Favorite color (mention only one) Liter of milk bought in home  \
# 5                            Purple                      0.5 - 1
# 7                            Yellow                      1.5 - 2
#
#   Height ( in cm)  Weight ( in Kg)  which is your favorite subject  \
# ...

# %%
data.head(2)
# Out:
#                 Timestamp           Email address        Name   District  \
# 0 2023-04-12 10:02:14.576  rithunhomiez@gmail.com  Rithun P C  Kozhikode
# 1 2023-04-12 10:02:48.677      anjupk84@gmail.com    Anju P K  Kozhikode
#
#   Designation  Gender Blood grouop            Education  Age Family members  \
# 0     Trainee    Male         B+ve  Degree (Graduation)   27            5-6
# 1     Trainee  Female         A+ve  Degree (Graduation)   29            3-4
#
#    ... No. of knives at home No. of chairs at home  \
# 0  ...                   0-3                  6-10
# 1  ...                   4-6                  6-10
#
#   Favorite color (mention only one) Liter of milk bought in home  \
# 0                             Black                      1 - 1.5
# 1                              Rose                      0.5 - 1
#
#   Height ( in cm)  Weight ( in Kg)  which is your favorite subject  \
# 0             176               68                  Data Analytics
# ...

# %%
data.sample(3)
# Out:
#                 Timestamp              Email address             Name  \
# 1 2023-04-12 10:02:48.677         anjupk84@gmail.com         Anju P K
# 9 2023-04-12 10:15:21.457  christy231johns@gmail.com  Catherine Johns
# 5 2023-04-12 10:08:47.065    Kanjanyathira@gmail.com        Athira pv
#
#     District Designation  Gender Blood grouop            Education  Age  \
# 1  Kozhikode     Trainee  Female         A+ve  Degree (Graduation)   29
# 9     Idukki      Mentor  Female         O-ve  Degree (Graduation)   21
# 5   Thrissur     Trainee  Female         A+ve  Degree (Graduation)   23
#
#   Family members  ... No. of knives at home No. of chairs at home  \
# 1            3-4  ...                   4-6                  6-10
# 9            3-4  ...                   0-3                16- 20
# 5            3-4  ...                   4-6                  6-10
#
#   Favorite color (mention only one) Liter of milk bought in home  \
# ...

# %%
data[['Age','Gender']].head(4)
# Out:
#    Age  Gender
# 0   27    Male
# 1   29  Female
# 2   21  Female
# 3   30    Male

# %%
data[1:5]
# Out:
#                 Timestamp              Email address             Name  \
# 1 2023-04-12 10:02:48.677         anjupk84@gmail.com         Anju P K
# 2 2023-04-12 10:04:18.475  aksharavincent7@gmail.com  Akshara Vincent
# 3 2023-04-12 10:06:17.104       ajeshc1992@gmail.com          Ajesh C
# 4 2023-04-12 10:08:34.463   jiyaparackal00@gmail.com      Jiyamol Joy
#
#     District Designation  Gender Blood grouop                Education  Age  \
# 1  Kozhikode     Trainee  Female         A+ve      Degree (Graduation)   29
# 2     Kannur     Trainee  Female         O+ve  12th (Higher Secondary)   21
# 3  Alappuzha     Trainee    Male         B+ve      Degree (Graduation)   30
# 4  Ernakulam     Trainee  Female         B+ve      Degree (Graduation)   27
#
#   Family members  ... No. of knives at home No. of chairs at home  \
# 1            3-4  ...                   4-6                  6-10
# 2            3-4  ...                   4-6                  6-10
# ...

# %%
data[3:6] #it will shows 3,4,5 of the data.
# Out:
#                 Timestamp             Email address         Name   District  \
# 3 2023-04-12 10:06:17.104      ajeshc1992@gmail.com      Ajesh C  Alappuzha
# 4 2023-04-12 10:08:34.463  jiyaparackal00@gmail.com  Jiyamol Joy  Ernakulam
# 5 2023-04-12 10:08:47.065   Kanjanyathira@gmail.com    Athira pv   Thrissur
#
#   Designation  Gender Blood grouop            Education  Age Family members  \
# 3     Trainee    Male         B+ve  Degree (Graduation)   30            5-6
# 4     Trainee  Female         B+ve  Degree (Graduation)   27            5-6
# 5     Trainee  Female         A+ve  Degree (Graduation)   23            3-4
#
#    ... No. of knives at home No. of chairs at home  \
# 3  ...                   0-3                   0-5
# 4  ...                   0-3                   0-5
# 5  ...                   4-6                  6-10
#
#   Favorite color (mention only one) Liter of milk bought in home  \
# 3                               Red                      1 - 1.5
# ...

# %%
data[1:8]
# Out:
#                 Timestamp              Email address             Name  \
# 1 2023-04-12 10:02:48.677         anjupk84@gmail.com         Anju P K
# 2 2023-04-12 10:04:18.475  aksharavincent7@gmail.com  Akshara Vincent
# 3 2023-04-12 10:06:17.104       ajeshc1992@gmail.com          Ajesh C
# 4 2023-04-12 10:08:34.463   jiyaparackal00@gmail.com      Jiyamol Joy
# 5 2023-04-12 10:08:47.065    Kanjanyathira@gmail.com        Athira pv
# 6 2023-04-12 10:09:44.593       alfynp2000@gmail.com         Alfy N P
# 7 2023-04-12 10:10:12.832  christy123johns@gmail.com    Christy Johns
#
#     District Designation  Gender Blood grouop                Education  Age  \
# 1  Kozhikode     Trainee  Female         A+ve      Degree (Graduation)   29
# 2     Kannur     Trainee  Female         O+ve  12th (Higher Secondary)   21
# 3  Alappuzha     Trainee    Male         B+ve      Degree (Graduation)   30
# 4  Ernakulam     Trainee  Female         B+ve      Degree (Graduation)   27
# ...

# %%
data[7:9]
# Out:
#                 Timestamp                Email address            Name  \
# 7 2023-04-12 10:10:12.832    christy123johns@gmail.com   Christy Johns
# 8 2023-04-12 10:14:03.385  remyaraghavan1999@gmail.com  Remya Raghavan
#
#     District Designation  Gender Blood grouop                Education  Age  \
# 7  Ernakulam      Mentor  Female         O+ve  Degree(Post Graduation)   24
# 8  Ernakulam     Trainee  Female         O+ve      Degree (Graduation)   23
#
#   Family members  ... No. of knives at home No. of chairs at home  \
# 7            3-4  ...                   4-6                 11-15
# 8            5-6  ...                   0-3                  6-10
#
#   Favorite color (mention only one) Liter of milk bought in home  \
# 7                            Yellow                      1.5 - 2
# 8                             Black                      1 - 1.5
#
#   Height ( in cm)  Weight ( in Kg)  which is your favorite subject  \
# ...

# %%
data[0:4]
# Out:
#                 Timestamp              Email address             Name  \
# 0 2023-04-12 10:02:14.576     rithunhomiez@gmail.com       Rithun P C
# 1 2023-04-12 10:02:48.677         anjupk84@gmail.com         Anju P K
# 2 2023-04-12 10:04:18.475  aksharavincent7@gmail.com  Akshara Vincent
# 3 2023-04-12 10:06:17.104       ajeshc1992@gmail.com          Ajesh C
#
#     District Designation  Gender Blood grouop                Education  Age  \
# 0  Kozhikode     Trainee    Male         B+ve      Degree (Graduation)   27
# 1  Kozhikode     Trainee  Female         A+ve      Degree (Graduation)   29
# 2     Kannur     Trainee  Female         O+ve  12th (Higher Secondary)   21
# 3  Alappuzha     Trainee    Male         B+ve      Degree (Graduation)   30
#
#   Family members  ... No. of knives at home No. of chairs at home  \
# 0            5-6  ...                   0-3                  6-10
# 1            3-4  ...                   4-6                  6-10
# ...

# %%
data[-1:-4]
# Out:
# Empty DataFrame
# Columns: [Timestamp, Email address, Name, District, Designation, Gender, Blood grouop, Education, Age, Family members, Shirt size, No. of knives at home, No. of chairs at home, Favorite color (mention only one), Liter of milk bought in home, Height ( in cm), Weight ( in Kg), which is your favorite subject, Which is your favorite Software, How many liter of water you drink daily, Favorite food ]
# Index: []
#
# [0 rows x 21 columns]

# %%
data[-1:]
# Out:
#                 Timestamp              Email address             Name  \
# 9 2023-04-12 10:15:21.457  christy231johns@gmail.com  Catherine Johns
#
#   District Designation  Gender Blood grouop            Education  Age  \
# 9   Idukki      Mentor  Female         O-ve  Degree (Graduation)   21
#
#   Family members  ... No. of knives at home No. of chairs at home  \
# 9            3-4  ...                   0-3                16- 20
#
#   Favorite color (mention only one) Liter of milk bought in home  \
# 9                             Black                   Not buying
#
#   Height ( in cm)  Weight ( in Kg)  which is your favorite subject  \
# 9             149               45                  Data Analytics
#
#   Which is your favorite Software How many liter of water you drink daily  \
# 9                   Excel and PBI                                     2.0
#
#    Favorite food
# 9             Veg
#
# [1 rows x 21 columns]

# %%
data[-6:]
# Out:
#                 Timestamp                Email address             Name  \
# 4 2023-04-12 10:08:34.463     jiyaparackal00@gmail.com      Jiyamol Joy
# 5 2023-04-12 10:08:47.065      Kanjanyathira@gmail.com        Athira pv
# 6 2023-04-12 10:09:44.593         alfynp2000@gmail.com         Alfy N P
# 7 2023-04-12 10:10:12.832    christy123johns@gmail.com    Christy Johns
# 8 2023-04-12 10:14:03.385  remyaraghavan1999@gmail.com   Remya Raghavan
# 9 2023-04-12 10:15:21.457    christy231johns@gmail.com  Catherine Johns
#
#     District Designation  Gender Blood grouop                Education  Age  \
# 4  Ernakulam     Trainee  Female         B+ve      Degree (Graduation)   27
# 5   Thrissur     Trainee  Female         A+ve      Degree (Graduation)   23
# 6  Ernakulam     Trainee  Female         B+ve      Degree (Graduation)   22
# 7  Ernakulam      Mentor  Female         O+ve  Degree(Post Graduation)   24
# 8  Ernakulam     Trainee  Female         O+ve      Degree (Graduation)   23
# ...

# %%
data[1:-3]
# Out:
#                 Timestamp              Email address             Name  \
# 1 2023-04-12 10:02:48.677         anjupk84@gmail.com         Anju P K
# 2 2023-04-12 10:04:18.475  aksharavincent7@gmail.com  Akshara Vincent
# 3 2023-04-12 10:06:17.104       ajeshc1992@gmail.com          Ajesh C
# 4 2023-04-12 10:08:34.463   jiyaparackal00@gmail.com      Jiyamol Joy
# 5 2023-04-12 10:08:47.065    Kanjanyathira@gmail.com        Athira pv
# 6 2023-04-12 10:09:44.593       alfynp2000@gmail.com         Alfy N P
#
#     District Designation  Gender Blood grouop                Education  Age  \
# 1  Kozhikode     Trainee  Female         A+ve      Degree (Graduation)   29
# 2     Kannur     Trainee  Female         O+ve  12th (Higher Secondary)   21
# 3  Alappuzha     Trainee    Male         B+ve      Degree (Graduation)   30
# 4  Ernakulam     Trainee  Female         B+ve      Degree (Graduation)   27
# 5   Thrissur     Trainee  Female         A+ve      Degree (Graduation)   23
# ...

# %%
data[3:-2]
# Out:
#                 Timestamp              Email address           Name  \
# 3 2023-04-12 10:06:17.104       ajeshc1992@gmail.com        Ajesh C
# 4 2023-04-12 10:08:34.463   jiyaparackal00@gmail.com    Jiyamol Joy
# 5 2023-04-12 10:08:47.065    Kanjanyathira@gmail.com      Athira pv
# 6 2023-04-12 10:09:44.593       alfynp2000@gmail.com       Alfy N P
# 7 2023-04-12 10:10:12.832  christy123johns@gmail.com  Christy Johns
#
#     District Designation  Gender Blood grouop                Education  Age  \
# 3  Alappuzha     Trainee    Male         B+ve      Degree (Graduation)   30
# 4  Ernakulam     Trainee  Female         B+ve      Degree (Graduation)   27
# 5   Thrissur     Trainee  Female         A+ve      Degree (Graduation)   23
# 6  Ernakulam     Trainee  Female         B+ve      Degree (Graduation)   22
# 7  Ernakulam      Mentor  Female         O+ve  Degree(Post Graduation)   24
#
#   Family members  ... No. of knives at home No. of chairs at home  \
# ...

# %%
data[0:-3]
# Out:
#                 Timestamp              Email address             Name  \
# 0 2023-04-12 10:02:14.576     rithunhomiez@gmail.com       Rithun P C
# 1 2023-04-12 10:02:48.677         anjupk84@gmail.com         Anju P K
# 2 2023-04-12 10:04:18.475  aksharavincent7@gmail.com  Akshara Vincent
# 3 2023-04-12 10:06:17.104       ajeshc1992@gmail.com          Ajesh C
# 4 2023-04-12 10:08:34.463   jiyaparackal00@gmail.com      Jiyamol Joy
# 5 2023-04-12 10:08:47.065    Kanjanyathira@gmail.com        Athira pv
# 6 2023-04-12 10:09:44.593       alfynp2000@gmail.com         Alfy N P
#
#     District Designation  Gender Blood grouop                Education  Age  \
# 0  Kozhikode     Trainee    Male         B+ve      Degree (Graduation)   27
# 1  Kozhikode     Trainee  Female         A+ve      Degree (Graduation)   29
# 2     Kannur     Trainee  Female         O+ve  12th (Higher Secondary)   21
# 3  Alappuzha     Trainee    Male         B+ve      Degree (Graduation)   30
# ...

# %%
b=data['Gender'].value_counts() #counts

# %%
a=data['Gender'].value_counts(normalize=True) #to shows percentages values of these counts
a
# Out:
# Female    0.8
# Male      0.2
# Name: Gender, dtype: float64

# %%
a.plot(kind='pie') #to plot diagram for percentages values
# Out:
# <Axes: ylabel='Gender'>

# %%
b.plot(kind='bar')
# Out:
# <Axes: >

# %%
b1=data['District'].value_counts() #counts 
b1
# Out:
# Ernakulam    4
# Kozhikode    2
# Kannur       1
# Alappuzha    1
# Thrissur     1
# Idukki       1
# Name: District, dtype: int64

# %%
b1.plot(kind='bar')
# Out:
# <Axes: >

# %%
b1.plot(kind='pie')
# Out:
# <Axes: ylabel='District'>

# %%
b1.plot(kind='area')
# Out:
# <Axes: >

# %%
b2=data['How many liter of water you drink daily'].value_counts()
b2
# Out:
# 2.0    4
# 1.0    3
# 3.0    1
# 0.6    1
# 1.5    1
# Name: How many liter of water you drink daily, dtype: int64

# %%
b2.plot(kind='pie')
# Out:
# <Axes: ylabel='How many liter of water you drink daily'>

# %%
c2=data['No. of knives at home'].value_counts()
c2
# Out:
# 0-3    6
# 4-6    4
# Name: No. of knives at home, dtype: int64

# %%
c2.plot(kind='bar')
# Out:
# <Axes: >

# %%
import pandas as pd
import matplotlib.pyplot as plt #plt(plot)
data=pd.read_excel('Oorjja (Responses).xlsx')
data.head() #head
# Out:
#                 Timestamp              Email address             Name  \
# 0 2023-04-12 10:02:14.576     rithunhomiez@gmail.com       Rithun P C
# 1 2023-04-12 10:02:48.677         anjupk84@gmail.com         Anju P K
# 2 2023-04-12 10:04:18.475  aksharavincent7@gmail.com  Akshara Vincent
# 3 2023-04-12 10:06:17.104       ajeshc1992@gmail.com          Ajesh C
# 4 2023-04-12 10:08:34.463   jiyaparackal00@gmail.com      Jiyamol Joy
#
#     District Designation  Gender Blood grouop                Education  Age  \
# 0  Kozhikode     Trainee    Male         B+ve      Degree (Graduation)   27
# 1  Kozhikode     Trainee  Female         A+ve      Degree (Graduation)   29
# 2     Kannur     Trainee  Female         O+ve  12th (Higher Secondary)   21
# 3  Alappuzha     Trainee    Male         B+ve      Degree (Graduation)   30
# 4  Ernakulam     Trainee  Female         B+ve      Degree (Graduation)   27
#
#   Family members  ... No. of knives at home No. of chairs at home  \
# ...
